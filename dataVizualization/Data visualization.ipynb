# %%
height = float(input("Enter your Height:"))
weight = float(input('Enter your Weight:'))
BMI= weight/height**2
print('My Height in ft is {} and Weight is {}, so my BMI is:{}'.format(height,weight,BMI))
# Out:
# Enter your Height:5.9
# Enter your Weight:76
# My Height in ft is 5.9 and Weight is 76.0, so my BMI is:2.1832806664751505

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style='ticks',color_codes=True)

titanic = sns.load_dataset('titanic')
sns.catplot(x='sex',y='survived',hue='class',kind='bar',data=titanic)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style='ticks',color_codes=True)

titanic = sns.load_dataset('titanic')
p1= sns.countplot(x='sex',data = titanic,hue='class')
p1.set_title('Plot for counting')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style='ticks',color_codes=True)

titanic = sns.load_dataset('titanic')
p1= sns.FacetGrid(titanic,row='sex',hue='alone')
p1=(p1.map(plt.scatter,'age','fare').add_legend())
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style='darkgrid',color_codes=True)
ship= sns.load_dataset('titanic')
p= sns.countplot(x='sex',data=ship,hue='class')
p.set_title('Basic count Plot')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style='darkgrid',color_codes=True)
ship= sns.load_dataset('titanic')
ship
# p= sns.countplot(x='sex',data=ship,hue='class')
# p.set_title('Basic count Plot')
# plt.show()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style='darkgrid',color_codes=True)
ship= sns.load_dataset('titanic')
p= sns.countplot(x='survived',data=ship,hue='who')
p.set_title('Basic count Plot')
plt.show()
# ------------------
sns.set_theme(style='ticks',color_codes=True)
titanic = sns.load_dataset('titanic')
sns.catplot(x='sex',y='survived',hue='class',kind='bar',data=titanic)
plt.show()
# ---------------
sns.set_theme(style='ticks',color_codes=True)
titanic = sns.load_dataset('titanic')
p1= sns.countplot(x='sex',data = titanic,hue='class')
p1.set_title('Plot for counting')
plt.show()
# -------------------
sns.set_theme(style='ticks',color_codes=True)

titanic = sns.load_dataset('titanic')
p1= sns.FacetGrid(titanic,row='sex',hue='alone')
p1=(p1.map(plt.scatter,'age','fare').add_legend())
plt.show()

# %% [markdown]
# <!-- Line Plot -->

# %%
import seaborn as sns
import matplotlib.pyplot as plt
flower = sns.load_dataset('iris')
# flower

sns.lineplot(x='sepal_length',y='sepal_width',data=flower)
plt.title("Sepal Analysis")
plt.show()

# %% [markdown]
# # Set style

# %%
import seaborn as sns
import matplotlib.pyplot as plt
flower = sns.load_dataset('iris')
# flower

sns.lineplot(x='sepal_length',y='sepal_width',data=flower)
plt.title("Sepal Analysis")
sns.set_style("darkgrid")
plt.show()

# %% [markdown]
# # Resolving error in style while using set_style('dark')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
flower = sns.load_dataset('iris')
# flower
sns.set_style(style=None,rc=None)
sns.lineplot(x='sepal_length',y='sepal_width',data=flower)
plt.title("Sepal Analysis")
sns.set_style("dark")
plt.show()

# %% [markdown]
# # Change Figure size

# %%
import seaborn as sns
import matplotlib.pyplot as plt
flower = sns.load_dataset('iris')
# flower

plt.figure(figsize=(8,8))
sns.lineplot(x='sepal_length',y='sepal_width',data=flower)
plt.title("Sepal Analysis")
sns.set_style("dark")
sns.set_style(style=None,rc=None)
plt.show()

# %% [markdown]
# # Barplot
#  -we will use previous code and then modify it for barplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
flower= sns.load_dataset('iris')
flower
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
flower= sns.load_dataset('iris')
# draw a barplot
sns.barplot(x='species',y='sepal_width',data=flower)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
flower= sns.load_dataset('iris')
# draw a barplot
sns.barplot(x='species',y='petal_length',data=flower)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
ship= sns.load_dataset('titanic')
# draw a barplot
sns.barplot(x='who',y='alone',hue='sex',data=ship)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
ship= sns.load_dataset('titanic')
# draw a barplot
sns.barplot(x='sex',y='alone',hue='who',data=ship)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
ship= sns.load_dataset('titanic')
# draw a barplot
sns.barplot(x='sex',y='alone',hue='who',data=ship,order=['female','male'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
ship= sns.load_dataset('titanic')
# draw a barplot
sns.barplot(x='sex',y='alone',hue='who',data=ship,order=['female','male'],color='grey')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# load dataset
ship= sns.load_dataset('titanic')
# draw a barplot
sns.barplot(x='sex',y='alone',hue='who',
            data=ship,order=['female','male'],
            color='red',ci=None,
           palette='muted')
plt.show()

# %%
# Estimators
import seaborn as sns
import numpy  as np
import matplotlib.pyplot as plt
# load dataset
ship= sns.load_dataset('titanic')
# draw a barplot
sns.barplot(x='sex',y='fare',hue='who',
            data=ship,
            color='red',estimator=median,
           palette='muted',ci=None)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\dataSci\DataAnalysis\Analysis\Data visualization.ipynb Cell 25 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/dataSci/DataAnalysis/Analysis/Data%20visualization.ipynb#ch0000024?line=0'>1</a> # Estimators
# ----> <a href='vscode-notebook-cell:/d%3A/dataSci/DataAnalysis/Analysis/Data%20visualization.ipynb#ch0000024?line=1'>2</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/d%3A/dataSci/DataAnalysis/Analysis/Data%20visualization.ipynb#ch0000024?line=2'>3</a> import numpy
#       <a href='vscode-notebook-cell:/d%3A/dataSci/DataAnalysis/Analysis/Data%20visualization.ipynb#ch0000024?line=3'>4</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# saturation------
import seaborn as sns
import numpy  
import matplotlib.pyplot as plt
# load dataset
ship= sns.load_dataset('titanic')
# draw a barplot
sns.barplot(x='sex',y='fare',hue='who',
            data=ship,
            color='red',estimator=median,
           palette='muted',ci=None,saturation=1.5)
plt.show()

# %%
# Horizontal plot------
import seaborn as sns
import numpy  as np
import matplotlib.pyplot as plt
# load dataset
ship= sns.load_dataset('titanic')
# draw a barplot
sns.barplot(x='fare',y='sex',hue='who',
            data=ship,
            color='red',estimator=median,
           palette='muted',ci=None,saturation=1)
plt.show()

# %%
# Horizontal plot------
import seaborn as sns
import numpy  
import matplotlib.pyplot as plt
# load dataset
ship= sns.load_dataset('titanic')
# draw a barplot
sns.barplot(x='class',y='fare',data=ship,
            linewidth=3,facecolor=(1,0.3,0.6,1),errcolor='0.6',edgecolor='0.2')
plt.show()
