# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load dataframs AGRI_LAND
df_agri_land = pd.read_csv('agri_land.csv')
df_agri_land
# Out:
#     DomainCode    Domain  AreaCode      Area  ElementCode Element  ItemCode  \
# 0           RL  Land Use       165  Pakistan         5110    Area      6621
# 1           RL  Land Use       165  Pakistan         5110    Area      6650
# 2           RL  Land Use       165  Pakistan         5110    Area      6655
# 3           RL  Land Use       165  Pakistan         5110    Area      6655
# 4           RL  Land Use       165  Pakistan         5110    Area      6650
# ..         ...       ...       ...       ...          ...     ...       ...
# 175         RL  Land Use       165  Pakistan         5110    Area      6650
# 176         RL  Land Use       165  Pakistan         5110    Area      6655
# 177         RL  Land Use       165  Pakistan         5110    Area      6655
# 178         RL  Land Use       165  Pakistan         5110    Area      6650
# 179         RL  Land Use       165  Pakistan         5110    Area      6621
#
# ...

# %%
#load dataframe of furtilizer_used
df_fur_use = pd.read_csv('furtilizer_used.csv')
df_fur_use
# Out:
#     DomainCode                   Domain  AreaCode      Area  ElementCode  \
# 0          RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 1          RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 2          RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 3          RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 4          RFN  Fertilizers by Nutrient       165  Pakistan         5157
# ..         ...                      ...       ...       ...          ...
# 170        RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 171        RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 172        RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 173        RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 174        RFN  Fertilizers by Nutrient       165  Pakistan         5157
#
#               Element  ItemCode                             Item  YearCode  \
# ...

# %%
# Header values

# %%
df_fur_use.head(5)
# Out:
#   Domain Code                   Domain  Area Code      Area  Element Code  \
# 0         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 1         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 2         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 3         RFN  Fertilizers by Nutrient        165  Pakistan          5157
# 4         RFN  Fertilizers by Nutrient        165  Pakistan          5157
#
#             Element  Item Code                             Item  Year Code  \
# 0  Agricultural Use       3102      Nutrient nitrogen N (total)       1961
# 1  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       1961
# 2  Agricultural Use       3103  Nutrient phosphate P2O5 (total)       1962
# 3  Agricultural Use       3102      Nutrient nitrogen N (total)       1962
# 4  Agricultural Use       3102      Nutrient nitrogen N (total)       1963
#
# ...

# %%
df_agri_land.head(5)
# Out:
#   Domain Code    Domain  Area Code      Area  Element Code Element  Item Code  \
# 0          RL  Land Use        165  Pakistan          5110    Area       6621
# 1          RL  Land Use        165  Pakistan          5110    Area       6650
# 2          RL  Land Use        165  Pakistan          5110    Area       6655
# 3          RL  Land Use        165  Pakistan          5110    Area       6655
# 4          RL  Land Use        165  Pakistan          5110    Area       6650
#
#                                     Item  Year Code  Year     Unit  Value  \
# 0                            Arable land       1961  1961  1000 ha  30580
# 1             Land under permanent crops       1961  1961  1000 ha    150
# 2  Land under perm. meadows and pastures       1961  1961  1000 ha   5000
# 3  Land under perm. meadows and pastures       1962  1962  1000 ha   5000
# 4             Land under permanent crops       1962  1962  1000 ha    150
#
# ...

# %%
# Describe Dataframes

# %%
df_agri_land.describe()
# Out:
#        Area Code  Element Code    Item Code    Year Code         Year  \
# count      180.0         180.0   180.000000   180.000000   180.000000
# mean       165.0        5110.0  6642.000000  1990.500000  1990.500000
# std          0.0           0.0    15.030695    17.366409    17.366409
# min        165.0        5110.0  6621.000000  1961.000000  1961.000000
# 25%        165.0        5110.0  6621.000000  1975.750000  1975.750000
# 50%        165.0        5110.0  6650.000000  1990.500000  1990.500000
# 75%        165.0        5110.0  6655.000000  2005.250000  2005.250000
# max        165.0        5110.0  6655.000000  2020.000000  2020.000000
#
#               Value
# count    180.000000
# mean   12093.350000
# std    13391.867412
# min      150.000000
# 25%      793.000000
# 50%     5000.000000
# 75%    30312.500000
# max    33140.000000

# %%
df_agri_land.head(5)
# Out:
#   DomainCode    Domain  AreaCode      Area  ElementCode Element  ItemCode  \
# 0         RL  Land Use       165  Pakistan         5110    Area      6621
# 1         RL  Land Use       165  Pakistan         5110    Area      6650
# 2         RL  Land Use       165  Pakistan         5110    Area      6655
# 3         RL  Land Use       165  Pakistan         5110    Area      6655
# 4         RL  Land Use       165  Pakistan         5110    Area      6650
#
#                                     Item  YearCode  Year     Unit  Value Flag  \
# 0                            Arable land      1961  1961  1000 ha  30580    W
# 1             Land under permanent crops      1961  1961  1000 ha    150    F
# 2  Land under perm. meadows and pastures      1961  1961  1000 ha   5000    F
# 3  Land under perm. meadows and pastures      1962  1962  1000 ha   5000    F
# 4             Land under permanent crops      1962  1962  1000 ha    150    F
#
# ...

# %%
df_al= df_agri_land.drop(['DomainCode','ItemCode','FlagDescription','AreaCode','ElementCode'],axis=1)
df_al
# Out:
#        Domain      Area Element                                   Item  \
# 0    Land Use  Pakistan    Area                            Arable land
# 1    Land Use  Pakistan    Area             Land under permanent crops
# 2    Land Use  Pakistan    Area  Land under perm. meadows and pastures
# 3    Land Use  Pakistan    Area  Land under perm. meadows and pastures
# 4    Land Use  Pakistan    Area             Land under permanent crops
# ..        ...       ...     ...                                    ...
# 175  Land Use  Pakistan    Area             Land under permanent crops
# 176  Land Use  Pakistan    Area  Land under perm. meadows and pastures
# 177  Land Use  Pakistan    Area  Land under perm. meadows and pastures
# 178  Land Use  Pakistan    Area             Land under permanent crops
# 179  Land Use  Pakistan    Area                            Arable land
#
#      YearCode  Year     Unit  Value Flag
# 0        1961  1961  1000 ha  30580    W
# ...

# %%
df_fur_use.head()
# Out:
#   DomainCode                   Domain  AreaCode      Area  ElementCode  \
# 0        RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 1        RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 2        RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 3        RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 4        RFN  Fertilizers by Nutrient       165  Pakistan         5157
#
#             Element  ItemCode                             Item  YearCode  \
# 0  Agricultural Use      3102      Nutrient nitrogen N (total)      1961
# 1  Agricultural Use      3103  Nutrient phosphate P2O5 (total)      1961
# 2  Agricultural Use      3103  Nutrient phosphate P2O5 (total)      1962
# 3  Agricultural Use      3102      Nutrient nitrogen N (total)      1962
# 4  Agricultural Use      3102      Nutrient nitrogen N (total)      1963
#
#    Year    Unit  Value Flag                                    FlagDescription
# ...

# %%
df_fu= df_fur_use.drop(['DomainCode','ItemCode','FlagDescription','AreaCode','ElementCode','Flag'],axis=1)
df_fu
# Out:
#                       Domain      Area           Element  \
# 0    Fertilizers by Nutrient  Pakistan  Agricultural Use
# 1    Fertilizers by Nutrient  Pakistan  Agricultural Use
# 2    Fertilizers by Nutrient  Pakistan  Agricultural Use
# 3    Fertilizers by Nutrient  Pakistan  Agricultural Use
# 4    Fertilizers by Nutrient  Pakistan  Agricultural Use
# ..                       ...       ...               ...
# 170  Fertilizers by Nutrient  Pakistan  Agricultural Use
# 171  Fertilizers by Nutrient  Pakistan  Agricultural Use
# 172  Fertilizers by Nutrient  Pakistan  Agricultural Use
# 173  Fertilizers by Nutrient  Pakistan  Agricultural Use
# 174  Fertilizers by Nutrient  Pakistan  Agricultural Use
#
#                                 Item  YearCode  Year    Unit    Value
# 0        Nutrient nitrogen N (total)      1961  1961  tonnes    41659
# 1    Nutrient phosphate P2O5 (total)      1961  1961  tonnes      500
# ...

# %%
df_fu.head(3)
# Out:
#                     Domain      Area           Element  \
# 0  Fertilizers by Nutrient  Pakistan  Agricultural Use
# 1  Fertilizers by Nutrient  Pakistan  Agricultural Use
# 2  Fertilizers by Nutrient  Pakistan  Agricultural Use
#
#                               Item  YearCode  Year    Unit  Value
# 0      Nutrient nitrogen N (total)      1961  1961  tonnes  41659
# 1  Nutrient phosphate P2O5 (total)      1961  1961  tonnes    500
# 2  Nutrient phosphate P2O5 (total)      1962  1962  tonnes    210

# %%
df_al.head()
# Out:
#      Domain      Area Element                                   Item  \
# 0  Land Use  Pakistan    Area                            Arable land
# 1  Land Use  Pakistan    Area             Land under permanent crops
# 2  Land Use  Pakistan    Area  Land under perm. meadows and pastures
# 3  Land Use  Pakistan    Area  Land under perm. meadows and pastures
# 4  Land Use  Pakistan    Area             Land under permanent crops
#
#    YearCode  Year     Unit  Value Flag
# 0      1961  1961  1000 ha  30580    W
# 1      1961  1961  1000 ha    150    F
# 2      1961  1961  1000 ha   5000    F
# 3      1962  1962  1000 ha   5000    F
# 4      1962  1962  1000 ha    150    F

# %%
df_agri_land.value_counts(['Value'])
# Out:
# Value
# 5000     60
# 793       4
# 150       3
# 160       3
# 165       3
#          ..
# 672       1
# 664       1
# 658       1
# 652       1
# 33140     1
# Length: 99, dtype: int64

# %%
df_al.groupby(['Year']).mean()
# Out:
#       YearCode         Value
# Year
# 1961    1961.0  11910.000000
# 1962    1962.0  11946.666667
# 1963    1963.0  11960.000000
# 1964    1964.0  12118.333333
# 1965    1965.0  12411.666667
# 1990    1990.0  6.309663e+05
# 1991    1991.0  6.280443e+05
# ...

# %%
df_fur_use
# Out:
#     DomainCode                   Domain  AreaCode      Area  ElementCode  \
# 0          RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 1          RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 2          RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 3          RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 4          RFN  Fertilizers by Nutrient       165  Pakistan         5157
# ..         ...                      ...       ...       ...          ...
# 170        RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 171        RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 172        RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 173        RFN  Fertilizers by Nutrient       165  Pakistan         5157
# 174        RFN  Fertilizers by Nutrient       165  Pakistan         5157
#
#               Element  ItemCode                             Item  YearCode  \
# ...

# %%
df_fu
# Out:
#                       Domain      Area           Element  \
# 0    Fertilizers by Nutrient  Pakistan  Agricultural Use
# 1    Fertilizers by Nutrient  Pakistan  Agricultural Use
# 2    Fertilizers by Nutrient  Pakistan  Agricultural Use
# 3    Fertilizers by Nutrient  Pakistan  Agricultural Use
# 4    Fertilizers by Nutrient  Pakistan  Agricultural Use
# ..                       ...       ...               ...
# 170  Fertilizers by Nutrient  Pakistan  Agricultural Use
# 171  Fertilizers by Nutrient  Pakistan  Agricultural Use
# 172  Fertilizers by Nutrient  Pakistan  Agricultural Use
# 173  Fertilizers by Nutrient  Pakistan  Agricultural Use
# 174  Fertilizers by Nutrient  Pakistan  Agricultural Use
#
#                                 Item  YearCode  Year    Unit    Value
# 0        Nutrient nitrogen N (total)      1961  1961  tonnes    41659
# 1    Nutrient phosphate P2O5 (total)      1961  1961  tonnes      500
# ...

# %%
fu =  df_fu[df_fu['Value'] >5000 ].groupby(['Item','Year']).mean()
fu
# Out:
#                                   YearCode    Value
# Item                        Year
# Nutrient nitrogen N (total) 1961    1961.0  41659.0
#                             1962    1962.0  41160.0
#                             1963    1963.0  67620.0
#                             1964    1964.0  84147.0
#                             1965    1965.0  69242.0
# ...                                    ...      ...
# Nutrient potash K2O (total) 2016    2016.0  28954.0
#                             2017    2017.0  54173.0
#                             2018    2018.0  54173.0
#                             2019    2019.0  47260.0
#                             2020    2020.0  60973.0
#
# [158 rows x 2 columns]

# %%
al = df_al[df_al['Value'] > 500].groupby(['Item','Year']).mean()
al
# Out:
#                                  YearCode    Value
# Item                       Year
# Arable land                1961    1961.0  30580.0
#                            1962    1962.0  30690.0
#                            1963    1963.0  30730.0
#                            1964    1964.0  31200.0
#                            1965    1965.0  32080.0
# ...                                   ...      ...
# Land under permanent crops 2016    2016.0    804.0
#                            2017    2017.0    793.0
#                            2018    2018.0    793.0
#                            2019    2019.0    793.0
#                            2020    2020.0    793.0
#
# [148 rows x 2 columns]
